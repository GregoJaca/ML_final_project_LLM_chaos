# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import torch
import io
import scipy.fftpack
import scipy.spatial
from sklearn.metrics.pairwise import cosine_distances
from scipy.cluster.hierarchy import linkage, leaves_list, cut_tree
import json
import sys

# %%
ds = [ "quantum_consciousness_hallucination/", "smartphones_society_impact/" ]

# %%
trs = []
for d in ds:
    trs.append(torch.load(d + "hidden_states_last.pt",map_location=torch.device('cpu')))
# Out:
# <ipython-input-28-bac2e5d9eb01>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trs.append(torch.load(d + "hidden_states_last.pt",map_location=torch.device('cpu')))

# %%
tr0 = np.concatenate((trs[0][0],trs[1][0]))
for tr in trs:
    print(tr.shape)
print(tr0.shape)
# Out:
# torch.Size([1, 1419, 1536])
# torch.Size([1, 1482, 1536])
# (2901, 1536)

# %%
ntr0 = (tr0.T / np.linalg.norm(tr0,axis=1)).T

# %%
np.dot(ntr0,ntr0[0])
# Out:
# array([ 0.99999994, -0.015562  ,  0.12708135, ..., -0.02697745,
#         0.04256708,  0.04230859], dtype=float32)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
ax1.plot(np.dot(ntr0,ntr0[0]))
ax2.plot(np.dot(ntr0,ntr0[10]))
ax3.plot(np.dot(ntr0,ntr0[100]))
ax4.plot(np.dot(ntr0,ntr0[1000]))
plt.show()

# %%
dm = cosine_distances(ntr0,ntr0)

# %%
plt.imshow(dm,cmap='gray')

# %%
ll0 = linkage(ntr0,'complete','cosine')

# %%
order = leaves_list(ll0)

# %%
dm = cosine_distances(ntr0[order],ntr0[order])
plt.imshow(dm,cmap='gray')

# %%
tokens = []
for d in ds:
    f = open(d+"tokens.json","r")
    tokens.append(json.load(f))
    f.close()

# %%
t = np.concatenate((np.array(tokens[0][:-1]),np.array(tokens[1])[:-1]))

# %%
t[order]
# Out:
# array([' system', ' it', 'measurement', ..., ' Oculus', 'AR', 'VR'],
#       dtype='<U21')

# %%
t
# Out:
# array(['<｜begin▁of▁sentence｜>', 'Ex', 'plain', ..., ' ethical',
#        ' implications', '.'], dtype='<U21')

# %%
(ll0[:,2]<0.1).sum()
# Out:
# 518

# %%
NC = 20
ct = cut_tree(ll0,n_clusters=NC).flatten()
for i in range(NC):
    print(t[np.where(ct==i)[0]])
# Out:
# ['<｜begin▁of▁sentence｜>' '<｜begin▁of▁sentence｜>' ' Smart' 'Smart' 'Smart']
# ['Ex' 'oss' 'oss' ' Below' ' is' ' research' ' are' ' discussed' '.' '  '
#  ' -' '.' '  ' '.' '  ' '.' '  ' '.' '  ' '###' 'oss' '.' ' Ex' '.' ' Ex'
#  '.' '###' '.' '**' '  ' '.' '**' '  ' '.' '**' '  ' '.' '**' '  ' '.'
#  '**' '  ' '###' '.' '**' '  ' '.' '**' '  ' '.' '**' '  ' '.' '**' '  '
#  '###' '.' '**' '  ' '.' '**' '  ' '.' '**' '  ' '###' 'oss' '---'
#  ' provides' 'oss' 'Ex' ' Con' ' Ex' ' Ex']
# ['plain' ' the' ' scientific' ' behind' ' the' ' quantum' ' consciousness'
#  ',' ' including' ' her' ' experimental' ',' ' key' ',' ' and' ' how'
#  ' her' ' Provide' ' detailed' ' and' ' from' ' her' ' published'
#  ' Additionally' ' discuss' ' the' ' of' ' clarify' ',' ' user' ' is'
#  ' student' ' who' ' is' ' trying' ' understand' ' and' ' needs' ' a'
#  ' comprehensive' ' They' ' may' ' have' ' a' ' basic' ' but' ' may'
#  ' not' ' be' ' familiar' ' user' ' is' ' looking' ' for' ' a' ' detailed'
#  ',' ' including' ' all' ' the' ' necessary' ',' ',' ' and' ' of'
#  ' behind' ',' ' including' ',' ' and' ' how' ',' ' of' ' which' ' in'
#  ' in' ' If' ' of' ' For' ',' ' of' ' behind' ',' ' including' ',' ' and'
#  ' how' ' discusses' ' of' 'plain' ' in' ' detail' ' how' ' Cover'
#  ' aspects' ' Provide' ' each' ' discuss' 'clude' ' with' ' Use' ' formal'
#  ' and' ' academic' ' Avoid' ' using' ' any' ' markdown' ' or'
#  ' formatting' 'Alright' ',' ' need' ' The' ' user' ' wants' ' detailed'
#  ' Each' ' have' ' Then' ',' ' conclude' ' in' ' formal' ' academic'
#  'First' ',' 'Next' ' need' ' ensure' ' each' ' section' ' is' ' with'
#  ' Use' ' formal' ' academic' ' without' ' markdown' 'Wait' ',' ' in'
#  ' the' ' initial' ',' ' the' ' user' ' provided' ' a' ' detailed'
#  ' Maybe' ' follow' ' a' ' similar' ' ensure' ' it' "'s" ' and' ' think'
#  ' outline' ' each' ',' ' flesh' ' them' ' with' ' Make' ' sure' ' all'
#  ' as' ' conclude' ' need' ' avoid' ' markdown' ',' ' so' ' stick' ' to'
#  ' plain' ' text' ' with' ' clear' ' and' ' Each' ' flow' ' logically'
#  ' to' ' the' ' next' 'Also' ',' ' ensure' ' that' ' each' ' example'
#  ' is' ' and' ' tied' ' the' 'In' ' the' ',' ' and' ' then' 'Let' ' make'
#  ' sure' ' miss' ' any' ' of' ' the' ' required' ' Each' ' needs' ' a'
#  ' detailed' ' check' ' that' ' each' ' section' ' has' ',' ' each'
#  ' need' ' ensure' ' that' ' the' ' language' ',' ' avoiding' ' any' 'ial'
#  ' Each' ' be' ' and' ',' ' to' ' be' 'In' ' the' ',' ' need' ' make'
#  ' sure' ' each' ' section' ' starts' ' with' ' a' ' clear' ' topic'
#  ' sentence' ',' ' followed' ' by' ',' ' and' ' ends' ' a' ' conclusion'
#  ' that' ' ties' ' back' 'Let' ' review' ' the' ' initial' ' ensure' "'t"
#  ' missed' ' any' ' key' ' or' ' included' ' any' '-required' ' The'
#  ' user' ' provided' ' a' ' detailed' ',' ' so' ' aim' ' follow' ' that'
#  ',' ' ensuring' ' think' "'ve" ' covered' ' all' ' the' ' required'
#  ' Now' ',' ' structure' ' my' ',' ' making' ' sure' ' each' ' section'
#  ' is' ',' ' examples' ' are' ' the' ' implications' ' are' 'Finally' ','
#  ' conclude' ' and' ' then' ' keeping' ' the' ' as']
# [' principles' ' theory' ' proposed' ' setup' ' findings'
#  ' interpretation' ' mechanics' ' equations' ' citations' ' papers' ','
#  ' implications' ' theory' ' computing' ' research' 'To' ' to' ' theory'
#  ' explanation' ' understanding' ' mechanics' ' specifics'
#  ' consciousness' ' breakdown' ' principles' ' equations' ' references'
#  ' intersection' ' mechanics' ' research' ' explanation' ' principles'
#  ' theory' ' setup' ' findings' ' interpretation' ' mechanics'
#  ' Additionally' ' implications' ' theory' ' future' ' computing'
#  ' mechanics' 'position' ' states' ' measured' ' suggests' 'position'
#  ' states' ',' ' each' ' corresponding' ' state' ' perception' ' such'
#  ' distance' ' proposes' 'ness' ' consciousness' ' brains'
#  ' interpretation' ' systems' ' coherence' ' due' ' interaction'
#  ' environment' ' nature' ' consciousness' ' system' ' interaction'
#  ' environment' ',' ' rather' 'herence' ' systems' ' interference'
#  ' patterns' ',' ' attributes' ' interference' ' consciousness' ' states'
#  ' thought' ' to' ' perception' ' states' ' systems' ' behavior' ','
#  ' measured' ' suggests' '-dependent' ',' ' contexts' ' leading' ' states'
#  ' information' ' processing' ' such' ' perception' ' decision' '-making'
#  ' memory' ' proposes' ' information' ' functioning' ' brain'
#  ' consciousness' ' involves' ' systems' ' that' ' brain' ' structure'
#  ' function' ' may' ' include' ' photons' ' lasers' ' systems' ' to'
#  ' activity' ' consciousness' ' Testing' ' algorithms' ' that'
#  ' information' ',' ' potentially' ' consciousness' 'ining' ' mechanics'
#  ' with' 'aging' ' to' ' activity' ' consciousness' ' argues'
#  ' phenomenon' ',' ' interaction' ' systems' ' environment' ' different'
#  ' experience' ' described' ' interpretation' ' suggests' ' patterns'
#  ' perception' ' states' ' thought' ' to' ' consciousness' ' states'
#  '-dependent' ',' ' contexts' ' leading' ' states' ' proposes' 'uality'
#  ' brain' ' may' ' involve' ' experiments' 'uality' ',' ' performed'
#  ' suggests' ' information' ' functioning' ' brain' ' consciousness'
#  ' processing' ' information' ' systems' ' such' ' as' ' photons' ','
#  ' to' ' activity' ' measurement' ',' ' nature' ' phenomena'
#  ' interpretation' ' by' ' proposing' ' phenomenon' ' interaction'
#  ' systems' ' environment' ' nature' ' consciousness' 'herence' ','
#  ' systems' ' coherence' ' due' ' interaction' ' environment' ' argues'
#  ' case' ',' ' interaction' ' systems' ' environment' 'ism' ',' ' fixed'
#  'istic' ',' ' outcomes' ' context' ' nature' ' consciousness' ','
#  ' brain' ' experience' ' nature' ' consciousness' ' nature' ' brain'
#  ' lack' ' definition' ' is' ' suggests' ' form' ' measurement' ','
#  ' interaction' ' systems' ' environment' ' form' ' computation' ','
#  ' then' ' computers' ' could' ' potentially' ' consciousness' ' or'
#  ' tasks' ' that' ' consciousness' ' would' ' implications' ' computing'
#  ' research' ' integration' ' mechanics' ' with' 'aging' ' could' ' lead'
#  ' to' ' new' ' insights' ' relationship' ' brain' ' consciousness'
#  ' example' ',' ' imaging' ' techniques' ' could' ' be' ' used' ' to'
#  ' interference' ' patterns' ' brain' ' could' ' development' ' theory'
#  ',' ' frameworks' ' for' ' systems' ' information' ' and'
#  ' consciousness' ' intersection' ' mechanics' ' research' ' By'
#  ' proposing' 'position' ' states' ' and' ' patterns' ' perception'
#  ' states' ' interpretation' ' mechanics' ' to' ' computing' ' research'
#  ',' ' perspectives' ' nature' ' consciousness' ' relationship' ' brain'
#  ' breakdown' ' principles' ' theory' ' setup' ' findings'
#  ' interpretation' ' mechanics' ' implications' ' theory' ' future'
#  ' computing' ' research' ' smartphones' ' society' ' communication'
#  ' habits' ' balance' ' education' ' entertainment' ' relationships'
#  ' examples' ' area' ' and' ' impacts' ' predictions' ' developments'
#  ' technology' ' usage' ' language' ' tone' ' I' ' to' ' smartphones'
#  ' society' ' explanations' ' habits' ' balance' ' education'
#  ' entertainment' ' relationships' ' section' ' should' ' examples'
#  ' impacts' ' predictions' ' tone' ' habits' ' I' "'ll" ' calls'
#  ' essential' ' points' ' communication' ' updates' ' sharing' ' usage'
#  ' devices' ' balance' ' phones' ' easier' ' to' ' information'
#  ' productivity' ' flexibility' ' consumption' ' overload' ' focus'
#  'Education' ' boards' ' learning' ' access' ' knowledge' ' engagement'
#  'ance' ' tools' ' lack' ' interaction' 'ertainment' ' consumption'
#  ' exposure' ' media' ' ideas' ' addiction' ' potential' ' loss'
#  ' interaction' ' relationships' ' reality' ' are' ' experiences'
#  ' connections' ' possibilities' ' isolation' ' reliance' ' platforms'
#  ' predictions' ' I' "'ll" ' advancements' ' AI' ' IoT' ' VR' 'AR'
#  ' impact' ' privacy' ' health' ' concerns' 'I' ' to' 'ained' ' examples'
#  ' impacts' ' language' ' response' ' breakdown' ' I' ' should'
#  ' structure' ' but' ' detailed' ' academic' 'I' ' I' ' should' ' section'
#  ' first' ' then' ' out' ' examples' ' implications' ' to' ' areas'
#  ' requested' ' and' ' trends' 'I' ' to' ' I' "'ll" ' sections'
#  ' paragraphs' ' point' ' should' ' specific' ' impact' ' instance'
#  ' apps' ' services' ' that' ' changes' ' conclusion' ' I' "'ll" ' impact'
#  ' developments' ',' ' technologies' ' considerations' ' me' ' I' ' don'
#  "'t" ' aspects' ' balance' ' education' ' entertainment' ' relationships'
#  ' explanation' 'I' ' should' ' also' ' examples' ' apps' ' services'
#  ' impact' ' example' ' balance' ' services' ' access' ' content' 'I'
#  ' to' ' formal' ' academic' ' terms' ' point' ' should' ' clear'
#  ' concise' ' detail' ' informative' ' predictions' ' I' "'ll"
#  ' advancements' ' AI' ' IoT' ' VR' 'AR' ' could' ' society' ','
#  ' perhaps' ' areas' ' learning' ' experiences' 'I' ' should' ' also'
#  ' impact' ' smartphones' ' people' ' example' ' can' ' connections'
#  ' but' ' also' ' isolation' 'I' ' to' ' examples' ' implications'
#  ' points' ' me' ' response' ' to' ' I' ' haven' ' areas' ' information'
#  ' response' ' I' ' should' ' to' ' structure' ' closely' ' completeness'
#  ' depth' 'I' ' I' ' aspects' ' I' "'ll" ' response' ' accordingly'
#  ' detailed' ' specific' 'ained' ' angles' ' I' "'ll" ' by' ' impact'
#  ' developments' ',' ' formal' ' academic' ' requested' ' smartphones'
#  ' we' ' interact' ' technology' ' and' ' society' ' impact' ','
#  ' balance' ' education' ' entertainment' ' relationships' ' smartphones'
#  ' areas' ',' ' examples' ' and' ' impacts' 'phones' ' tools'
#  ' communication' ' features' ' users' ' can' ' touch' ' anyone' ','
#  ' anywhere' ' instance' ' platforms' ' Facebook' ' Twitter' ' sharing'
#  ' content' ',' ' communication' ' However' ' usage' ',' ' potentially'
#  'loading' ' devices' ' strain' ' networks' ' smartphone' ' access'
#  ' information' ',' ' individuals' ' to' ' engage' ' content' ' topics'
#  ' Services' ' YouTube' ' Netflix' ' opportunities' ',' ' productivity'
#  ' However' ' divide' ' overload' ',' ' focus' 'out' 'phones' ' by'
#  ' access' ' content' ' platforms' ' platforms' 'a' 'X' ' accessible' ','
#  ' location' ' However' ' reliance' ' tools' ' loss' ' interaction' ','
#  ' students' ' struggling' ' to' ' connect' ' teachers' ' peers' ' person'
#  ' smartphone' ' consumption' ' range' ' media' ',' ' movies' ' users'
#  ' content' ',' ' sense' ' awareness' ' However' ' stream' ' information'
#  ' can' ' addiction' ',' ' users' ' who' ' may' ' quantity' ' quality'
#  ' smartphone' ' integration' 'VR' ' experiences' ' Platforms'
#  ' Pinterest' ' users' ' to' ' engage' ' experiences' ' interactions' ','
#  ' connections' ' However' ' reliance' ' platforms' ' can' ' isolation'
#  ',' ' users' ' may' ' presence' ' connections' ' smartphone' ' future'
#  ' development' ' to' ' advancements' ' intelligence' 'AI' ' Things' 'T'
#  ' reality' 'AR' ' assistants' ' platforms' ' could' ' Meanwhile'
#  ' considerations' ' such' ' privacy' ' impact' ' technology' ' health'
#  ',' ' will' ' smartphones' ' society' ',' ' education' ' entertainment'
#  ' interactions' ' they' ' opportunities' ' they' ' challenges'
#  ' distractions' ' relationship' ' technology' ' smartphone' ' to' ' role'
#  ' future' ' society' ' will' ' we' ' benefits' ' implications']
# [' by' ' Dr' '.' ' Elena' ' V' 'Dr' '.' ' Elena' 'Dr' '.' ' Elena' '-ex'
#  'pl' '-ex' 'pl' ' revolution' ' democrat' ' democrat']
# [' work' ' theory' ' work' ' until' 'oss' ' theory' ' consciousness'
#  'lement' ' particles' ' state' ' one' ' particle' ' instantly' ' state'
#  ' another' ',' 'oss' 'lement' 'oss' ' theory' 'oss' ' interference'
#  ' outcome' ' context' ' system' ' is' 'oss' ' consciousness' 'ness' 'oss'
#  ' processing' ' setup' ' likely' 'oss' ' consciousness' ' theory'
#  ' interference' ' interference' 'ness' 'oss' 'uality' 'oss' ' work'
#  ' outcome' ' measurement' ' context' ' it' ' is' ' theory' ' processing'
#  ' interpretation' ' mechanics' 'oss' ' theory' ' consciousness'
#  ' interpretation' 'oss' ' consciousness' ' interpretation' ' outcome'
#  ' measurement' 'oss' ' theory' ' mechanics' ' interpretation' 'oss'
#  ' theory' ' problem' ' mechanics' 'measurement' '"' 'oss' ' theory'
#  ' consciousness' ' consciousness' ' theory' ' theory' ' consciousness'
#  ' interference' 'oss' ' work' ' explanation' ' work' ' It' ' also'
#  ' have' ' have' ' have' ' have' ' have' ' has' ' have' ' have' ' section'
#  ' have' ' have' ' have' ' has' ' also' ' has' ' have' ' has' ' sometimes'
#  ' have' ' have' ' has' ' sometimes' ' has' ' has' ' has' ' have'
#  ' significantly' ' have' ' have' ' also']
# [' challenges' ' the' ' traditional' ' Copenhagen' ' of' ' this' ' for'
#  ' the' ' future' ' of' ' and' ' the' ' this' ' of' ' with' ' the' ' of'
#  ' The' ' scientific' "'s" ' consciousness' ' is' ' a' ' fascinating'
#  ' an' ' the' ' scientific' ' her' ' her' ' experimental' ',' ' key'
#  ' her' ' challenges' ' the' ' traditional' ' Copenhagen' ' of' ' the'
#  ' this' ' for' ' the' ' of' ' In' "'s" ' regardless' ' of' ' In' ' the'
#  ' Copenhagen' "'s" "'s" ' experimental' ' This' ' by' ' the'
#  ' Copenhagen' ' The' "'s" ' The' ' This' 'The' ' traditional'
#  ' Copenhagen' ' of' ' collapse' ' function' "'s" ' challenges' ' this'
#  ' The' ' Copenhagen' ' The' ' Copenhagen' "'s" ' The' ' Copenhagen' "'s"
#  ' The' ' measurement' ' in' "'s" ' This' ' have' ' significant' ' for'
#  ' both' ' The' ' The' ' influence' ' the' ' of' ' providing' ' new' "'s"
#  ' consciousness' ' is' ' a' ' groundbreaking' ' challenges' ' the'
#  ' traditional' ' Copenhagen' ' of' ' Her' ' has' ' the' ' potential'
#  ' influence' ' both' ' offering' ' new' 'This' ' a' ' detailed' ' the'
#  ' scientific' "'s" ' consciousness' ' her' ' experimental' ',' ' key'
#  ' her' ' challenges' ' the' ' traditional' ' Copenhagen' ' of' ' the'
#  ' this' ' for' ' the' ' of' ' modern' ',' '-life' ',' ',' ',' ' and'
#  ' social' ' positive' ' and' ' negative' ' future' ' smartphone' ' and'
#  ' changed' ' modern' ',' '-life' ',' ',' ',' ' and' ' social' ' specific'
#  ' and' ' discuss' ' both' ' positive' ' and' ' negative' ' with'
#  ' future' ',' ' mention' ' how' ' become' ' Positive' ':' ',' ','
#  ' Negative' ',' '-life' ' it' ',' ' leading' ' increased' ' Positive' ':'
#  ',' ' more' ' Negative' ' decreased' ' changed' ' to' ' Positive' ':'
#  ' diverse' ' education' ',' ' better' ' Negative' ' of' '-face' ' led'
#  ' Positive' ' Negative' ' of' '-face' 'Social' ' Virtual' ' changing'
#  ' Positive' ':' ',' ' social' ' Negative' ' digital' 'For' ' future'
#  ' Also' ',' ' of' ' and' ' and' ' both' ' positive' ' and' ' negative'
#  ' and' ' and' ' with' ' future' ' to' ' contribute' ' to' ' both'
#  ' positive' ' and' ' negative' ' summarize' ' the' ' overall' ' predict'
#  ' future' ' mentioning' ' emerging' ' and' ' ethical' ',' '-life' ',' ','
#  ',' ' social' ' specific' '-life' ' changed' ' to' ' is' ' and'
#  ' providing' ' enough' ' future' ' outline' ' impact' ' touching' ' on'
#  ' like' ' or' ' consider' ' the' ' emotional' ' of' ',' ' both'
#  ' positive' ' and' ' negative' ' lead' ' and' ' with' ' to' ' the'
#  ' main' ' and' ',' ' and' ' with' ' both' ' positive' ' and' ' negative'
#  'izing' ' the' ' overall' ' predict' ' future' ' language' ' and' 'In'
#  ' era' 'ized' ' way' ' with' ' is' 'eted' ' influencing' ',' '-life' ','
#  ',' ',' ' and' ' social' ' This' 'ves' ' transformed' ' these'
#  ' providing' ' specific' ' exploring' ' both' ' positive' ' and'
#  ' negative' ' become' ' integral' ' stay' ' in' ' fostering' ' led'
#  'ized' ' to' ' with' ' and' 'ized' ' education' ' and' ' career'
#  ' leading' ' to' ' increased' ' led' ' resulting' ' decreased'
#  ' transformed' ' education' ' enabling' ' to' ' and' ' made' ' education'
#  ' more' ' regardless' ' of' ' led' ' of' '-face' ' with' ' some' ' with'
#  ' and' ' in' ' lead' ' particularly' ' among' ' younger' ' social'
#  ' fostering' ' deeper' ' digital' ' lead' ' digital' ' over' '-face'
#  'Looking' ' ahead' ' is' ' likely' ' be' ' shaped' ' enhance' ' and'
#  ' education' ' ethical' ',' ' as' ' and' ' of' ' on' ' remain'
#  ' critical' ' areas' ' of' ' focus' 'In' ' conclusion' ' altered'
#  ' modern' 'aping' ',' ',' ',' ',' ' and' ' social' ' introduced' ' new'
#  ' brought' ',' ' particularly' ' in' ' and' ' ensuring' ' continues'
#  ' evolve' ',' ' in' ' shaping' ' of' ' depend' ' on' ' how' ' balance'
#  ' its' ' with' ' its' ' ethical']
# [' quantum' ' quantum' ' consciousness' ' quantum' ' quantum' ' quantum'
#  ' of' ' quantum' ' and' ' consciousness' ' quantum' ' quantum' ' and'
#  ' consciousness' ' quantum' ',' ' particles' ' exist' ' in' ' a' ' of'
#  ' that' ' is' ' a' ' quantum' ' of' ' different' ' to' ' a' ' different'
#  ' mental' ' or' ' Quantum' ' links' ' that' ' the' ' of' ' influences'
#  ' the' ' of' ' that' ' this' 'lies' ' the' ' interconnected' ' of'
#  ' across' ' different' ',' ' quantum' ' lose' ' their' ' to' ' with'
#  ' an' ' attributes' ' the' ' objective' ' of' ' to' ' the' "'s" ' with'
#  ' its' ' than' ' Quantum' ' exhibit' ' to' ' the' ' between' ' different'
#  ' This' ' is' 'lie' ' the' ' of' ' distinct' ' mental' ' Quantum'
#  ' exhibit' '-dependent' ' where' ' the' ' depends' ' on' ' the' ' which'
#  ' the' ' that' ' is' ' with' ' different' ' to' ' different' ' mental'
#  ' Conscious' ' involves' ',' ' as' ',' ',' ' and' ' that' ' quantum'
#  'lies' ' the' ' of' ' the' ' and' ' quantum' ' mimic' ' the' "'s" ' and'
#  ' Using' ',' ',' ' and' ' optical' ' simulate' ' neural' ' and'
#  ' quantum' ' process' ' quantum' 'ulating' ' quantum' ' study' ' brain'
#  ' and' ' that' ' is' ' an' ' objective' ' arising' ' from' ' the' ' of'
#  ' quantum' ' with' ' their' ' This' ' is' ' from' ' the' ' subjective'
#  ' that' ' quantum' 'lie' ' the' ' of' ' distinct' ' mental' ' This' ' is'
#  ' occur' ' between' ' different' ' Conscious' ' is' ' with' ' different'
#  ' to' ' different' ' mental' ' that' ' this' ' arises' ' from' ' quantum'
#  ' in' ' the' ' demonstrating' ' quantum' ' where' ' the' ' of' ' a'
#  ' quantum' ' depends' ' on' ' the' ' which' ' that' ' quantum' 'lies'
#  ' the' ' of' ' the' ' and' ' includes' ' the' ' of' ' in' ' quantum' ','
#  ' simulate' ' neural' ' quantum' ' describes' ' the' ' of' ' the' ' upon'
#  ' leading' ' to' ' the' 'istic' ' of' ' quantum' ' that' ' is' ' an'
#  ' objective' ' arising' ' from' ' the' ' of' ' quantum' ' with' ' their'
#  ' attributes' ' the' ' objective' ' of' ' to' ' where' ' quantum' ' lose'
#  ' their' ' to' ' with' ' an' ' that' ' this' ' is' ' not' ' the' ' and'
#  ' instead' ',' ' arises' ' from' ' the' ' of' ' quantum' ' with' ' their'
#  ' assumes' ' where' ' the' ' of' ' a' ' quantum' ' is' ' suggests'
#  ' that' ' quantum' ' is' ' inherently' ' with' ' different' ' depending'
#  ' on' ' the' ' quantum' ' emphasizes' ' the' ' subjective' ' of'
#  ' arising' ' from' ' the' "'s" ' subjective' ' attributes' ' the'
#  ' objective' ' of' ' to' ' the' ' quantum' ' of' ' the' ' quantum'
#  ' concerns' ' the' ' of' ' a' ' clear' ' of' ' what' ' a' ' that' ' is'
#  ' a' ' of' ' arising' ' from' ' the' ' of' ' quantum' ' with' ' their'
#  ' quantum' ' is' ' a' ' of' ' quantum' ' quantum' ' simulate' ' perform'
#  ' require' ' quantum' ' and' ' consciousness' ' quantum' ' into' ' the'
#  ' between' ' the' ' and' ' quantum' ' study' ' quantum' ' in' ' the'
#  ' quantum' ' information' ' understanding' ' how' ' quantum' ' process'
#  ' simulate' ' quantum' ' of' ' quantum' ' and' ' consciousness' ' that'
#  ' is' ' a' ' quantum' ' of' ' different' ' that' ' quantum' 'lie' ' the'
#  ' of' ' distinct' ' mental' ' quantum' ' quantum' ' and' ' consciousness'
#  ' on' ' the' ' of' ' and' ' its' ' to' ' the' ' quantum' ' quantum'
#  ' quantum' ' and' ' consciousness' ' mental']
# ['.' '.' '.' '.' '.' '.' '###' 'ific' ' Principles' ' Behind' ' Quantum'
#  'ness' ' Theory' 'um' 'position' ' and' 'lement' '  ' ' -' 'position'
#  '**:' '.' 'lement' '**:' '.' 'Objective' 'herence' ' -' 'herence' '**:'
#  '.' 'um' 'ference' ' -' 'ference' '**:' '.' 'um' ' Context' 'uality' ' -'
#  'Context' 'uality' '**:' '.' 'um' ' Information' ' -' 'Information'
#  ' Processing' '**:' '.' 'Experimental' ' Setup' '.' 'um' 'ics'
#  'periments' '**:' 'um' ' Computing' 'periments' '**:' 'aging'
#  ' Techniques' '**:' 'Key' 'ings' 'Objective' 'herence' ' -' '.' 'um'
#  'ference' ' -' '.' 'Context' 'uality' ' -' '.' 'um' ' Context' 'uality'
#  ' -' 'um' ' Information' ' Processing' ' -' '.' 'ing' ' the'
#  ' Traditional' ' Copenhagen' 'ation' '.' 'Objective' 'herence' ' -' '.'
#  'ism' ' -' '.' 'Objective' ' Reality' ' -' '.' 'Measurement' ' Problem'
#  ' -' '.' 'lications' ' for' ' Quantum' ' Computing' ' and' 'ness'
#  ' Research' 'um' ' Computing' ' -' '.' 'aging' ' -' '.' 'um'
#  ' Information' ' Theory' ' -' 'Conclusion' '.' '.' '.' '.' '.' '.' '.'
#  '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.'
#  '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' '.' 'The'
#  ' Evolution' ' of' '智能手机' ':' ' A' ' Comprehensive' ' Analysis' '.' '.'
#  '.' ' Communication' 'its' ':' ' Faster' ' and' ' More' ' Effective'
#  ' Communication' '.' '.' '.' '.' '-Life' ' Balance' ':' ' Access' ' to'
#  ' Information' ' and' ' Increased' 'ivity' '.' '.' '.' ' Education' ':'
#  'iverse' ' Access' ' and' ' New' 'periences' '.' '.' '.' ' Entertainment'
#  ':' ' Exposure' ' to' 'iverse' ' Media' ' and' ' Increased' ' Content'
#  ' Consumption' '.' '.' '.' ' Social' ' Relationships' ':' 'ersive'
#  'periences' ' and' ' New' ' Social' 'ibilities' '.' '.' 'Future' 'ions'
#  ':' 'ancements' ' and' 'ical' 'ations' ' of' ').' '.' '.' '.' '.']
# ['.\n' '.\n' '\n\n' '.\n\n' '---\n\n' ' **' '**\n\n' ' **' '**\n' ' **'
#  '.\n' ' **' '.\n\n' ' **' '**\n' ' **' '.\n\n' ' **' '**\n' ' **' '.\n\n'
#  ' **' '**\n' ' **' '.\n\n' ' **' '**\n' ' **' '.\n\n' '---\n\n' ' **'
#  '**\n\n' ':\n\n' ' **' '.\n' ' **' '.\n' ' **' '.\n\n' '---\n\n' ' **'
#  '**\n\n' ' **' ':\n' '.\n\n' ' **' ':\n' '.\n\n' ' **' ':\n' '.\n\n'
#  ' **' ':\n' '.\n\n' ' **' ':\n' '.\n\n' '---\n\n' ' **' '**\n\n' '.\n\n'
#  ' **' ':\n' '.\n\n' ' **' ':\n' '.\n\n' ' **' ':\n' '.\n\n' ' **' ':\n'
#  '.\n\n' '---\n\n' ' **' '**\n\n' ' **' ':\n' '.\n\n' ' **' ':\n' '.\n\n'
#  ' **' ':\n' '.\n\n' '---\n\n' ' **' '**\n\n' '.\n\n' ' \n\n' '.\n'
#  '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n'
#  '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n' '.\n\n'
#  '.\n\n' '.\n\n' '.\n\n' '\n\n' '**' '**\n\n' '.\n\n' '**' '**\n\n'
#  '.\n\n' '**' '**\n\n' '.\n\n' '**' '**\n\n' ' ed' '.\n\n' '**' '**\n\n'
#  '.\n\n' '**' '**\n\n' '.\n\n' '**' '**\n\n' '.\n\n']
# [' a' ' changed' ' like' ' specific' ' for' ' both' ' about' ' in'
#  ' explain' ' how' ' covering' ' communication' ' communication' ' SMS'
#  ' faster' '-time' ' easy' ':' ' high' ' data' ',' ' potential' ' for'
#  'loading' ' Mobile' ' made' ' access' ' to' ' content' ':' ' potential'
#  ' for' ' information' ',' ' and' ' online' ':' ' potential' ' for' ' on'
#  ' digital' ',' ' Social' ' media' ' to' ' increased' ' content' ':' ' to'
#  ' diverse' ',' ' new' ':' ',' ' reality' ' and' ' augmented' ' immersive'
#  ' new' ':' ' potential' ' for' ',' ' on' ',' ' suggest' ' in' ',' ','
#  ' and' ' the' ' data' ' cover' ' For' ' in' ' communication' ' specific'
#  ' or' ':' ' communication' ' specific' ' or' ' for' ' For' ' in'
#  ' streaming' ' how' ' in' ',' ',' ' and' ' personalized' ' immersive'
#  ' on' ' For' ',' ' how' ' social' ' media' ' foster' ' to' ' the'
#  ' modern' ',' ' the' ' Their' ' communication' ' into' ' how' ' for'
#  ' SMS' ' calls' ' video' 'encing' ',' ' with' ' For' ' social' ' media'
#  ' enabled' ' instant' ' of' '-time' ',' ' this' ' to' ' increased'
#  ' data' ' causing' ' of' ' and' ' the' ' on' ' cellular' 'The'
#  ' allowing' ' diverse' ',' ' this' ' digital' ' to' ' information' ' in'
#  ' and' ' diverse' ' Online' ' learning' ',' ' on' ' digital' ' to' ' a'
#  'The' ' facilitated' ' the' ' of' ' a' ' wide' ' of' ' entertainment'
#  ' from' ' gaming' ' and' ' streaming' ' to' ' music' ' and' ' This'
#  ' exposed' ' to' ' diverse' ' fostering' ' a' ' broader' ' of'
#  ' cultural' ',' ' the' ' constant' ' of' ' to' ' prioritize' ' over'
#  'The' "'s" ' with' ' augmented' ' and' ' virtual' ' reality' ')'
#  ' created' ' immersive' ' allow' ' in' ' virtual' ' reality' ' and'
#  ' social' ' media' ',' ' on' ' to' ' social' ' as' ' prioritize' ','
#  ' the' "'s" ' by' ' in' ' artificial' '),' ' the' '),' ' and' ' virtual'
#  ' AI' '-driven' ' personal' ' and' ' AI' '-powered' ' learning'
#  ' communication' ',' ' data' ' the' ',' ' communication' ' While' ','
#  ' managing' ' digital' ' a' ' healthy' ' with' ' As' ' the' ' its' ' the']
# ['</think>' ' sim' ' Comb' '-D' '-d' '-re' 'li' ' collo' 'qu' ' summar'
#  '.\n' '</think>' ' multif' 'ac' ' D' ' D' ' resh']
# [' V' '1' ' V' ' V' '2' ' V' '3' ' V' '4' ' V' '5' ' V' 'V' '1' '2' '3'
#  '1' ' V' '2' '3' ' V' '4' ' V' '5' ' V' '1' ' V' '2' ' V' '3' ' V' '4'
#  ' V' '1' '2' '3' ' V' ' V' ' V' '1' '2' '3' '4' '5']
# ['Scient' ' Conscious' 'Quant' ' Ent' 'ang' 'Ent' 'ang' ' ent' 'ang'
#  ' ent' 'ang' 'Quant' 'Quant' 'Quant' 'Quant' ' Opt' 'Quant' 'Ne' 'im'
#  'im' 'Quant' 'Quant' 'Quant' ' probabil' 'etermin' ' determin' 'etermin'
#  ' Conscious' 'Quant' 'Ne' 'im' 'im' 'Quant' 'Ent' ' Product' ' Imm']
# [' Super' 'Super' ' super' ' super' ' Dec' 'o' 'Dec' 'o' ' deco' ' Inter'
#  'Inter' 'uro' ' neuro' ' Dec' 'o' ' Inter' ' Interpret' ' Dec' 'o'
#  ' deco' ' "' 'uro' ' neuro' ' super' ' over' ' over' ' over']
# [' under' ' under' ' context' ' context' ' under' ' under' ' context'
#  ' context' ' context' ' context' ' under' ' wave' 'Non' ' non' ' under'
#  ' work' ' work' ' real' ' work' ' face' '-to' ' face' '-to' ' well'
#  ' work' ' work' ' non' ' well' ' work' ' real' ' Work' ' burn' ' face'
#  '-to' ' face' '-to' ' work']
# [' Find' 'Ch' 'alleng' 'Imp' ' del' ' Hab' ' confer' ' Poss' ' Predict'
#  ' Adv' ' Eth' ' Consider']
# [' and' ',' ',' ' mentioning' ' like' ' using' ',' ',' ' mentioning'
#  ' how' ' With' ' like' ',' ',' ' and' ',' ' like' ' and' ' like' ' and'
#  ' like' ' and' ' like' ' and']
# ['/' '/' ' (' '/' ' (' ' Internet' ' (' 'Io' ' (' '/']
# [' Cour' 'ser' 'AR' ' Oculus' 'VR']

# %%
c = [30,31,32,33,34,35,36,37,40,41,42,43,44,45,46,47]
NC = len(c)
c = [31,32,33,34,35,36,37,40,41,42,43,44,45,46,47]
NC =4

# %%
ct = cut_tree(ll0,n_clusters=NC).flatten()

# %%
f = open("a.txt","w")
for i in range(len(t)):
    f.write("\x1b[%dm%s\x1b[0m" % (c[ct[i]],t[i]))
f.close()

# %%
len(t)
# Out:
# 2901

# %%
len(ct)
# Out:
# 2901

# %%
for i in range(NC):
    plt.plot(np.where(ct==i)[0])
